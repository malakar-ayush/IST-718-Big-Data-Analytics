# %%
# ==============================================================================
#                      Project : Predicting Stock Price
# ==============================================================================


# Clear Screen
# 
print(chr(27) + "[2J")


# Banner
#
print('')
print('')
print('           # #                 # #                 # #      ')
print('           # #                 # #                 # #      ')
print('          $$$$$               $$$$$               $$$$$     ')
print('        $$ # # $$           $$ # # $$           $$ # # $$   ')
print('       $$$ # #             $$$ # #             $$$ # #      ')
print('        $$$# #              $$$# #              $$$# #      ')
print('          $$$#                $$$#                $$$#      ')
print('           #$$$                #$$$                #$$$     ')
print('           # #$$$              # #$$$              # #$$$   ')
print('           # # $$$             # # $$$             # # $$$  ')
print('       $$$ # #  $$$$       $$$ # #  $$$$       $$$ # #  $$$$')
print('        $$$# # $$$$         $$$# # $$$$         $$$# # $$$$ ')
print('          $$$$$$$             $$$$$$$             $$$$$$$   ')
print('           # #                 # #                 # #      ')
print('           # #                 # #                 # #      ')
print('')
print('')
# Out:
#            # #                 # #                 # #
#            # #                 # #                 # #
#           $$$$$               $$$$$               $$$$$
#         $$ # # $$           $$ # # $$           $$ # # $$
#        $$$ # #             $$$ # #             $$$ # #
#         $$$# #              $$$# #              $$$# #
#           $$$#                $$$#                $$$#
#            #$$$                #$$$                #$$$
#            # #$$$              # #$$$              # #$$$
#            # # $$$             # # $$$             # # $$$
#        $$$ # #  $$$$       $$$ # #  $$$$       $$$ # #  $$$$
#         $$$# # $$$$         $$$# # $$$$         $$$# # $$$$
#           $$$$$$$             $$$$$$$             $$$$$$$
#            # #                 # #                 # #
#            # #                 # #                 # #

# %%
import os

# %%
# ==============================================================================
# Enabling Logging
# ==============================================================================

import logging

# Logger Settings:
logging.basicConfig(level=logging.WARNING)
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')

def setup_logger(name, log_file, level=logging.INFO):
    """To setup as many loggers as you want"""
    handler = logging.FileHandler(log_file)        
    handler.setFormatter(formatter)
    logger = logging.getLogger(name)
    logger.setLevel(level)
    logger.addHandler(handler)
    return logger

# Phases Logger
phases_logger_file = 'log_phases.log'
os.system('rm -rf '+ phases_logger_file)
phases_logger = setup_logger('Phases', phases_logger_file)
phases_logger.info('Project : Predicting Stock Price')
phases_logger.info('Phases Logger Init')

# Details Logger
details_logger_file = 'log_details.log'
os.system('rm -rf '+ details_logger_file)
details_logger = setup_logger('Details', details_logger_file)
details_logger.info('Project : Predicting Stock Price')
details_logger.info('Details Logger Init')
# Out:
# INFO:Phases:Project : Predicting Stock Price
# INFO:Phases:Phases Logger Init
# INFO:Details:Project : Predicting Stock Price
# INFO:Details:Details Logger Init

# %%
# ==============================================================================
# Importing Basic Packages
# ==============================================================================

phases_logger.info('Importing Basic Packages : Start')

details_logger.info('Import : re')
import re

details_logger.info('Import : os')
import os

details_logger.info('Import : sys')
import sys

phases_logger.info('Importing Basic Packages : End')
# Out:
# INFO:Phases:Importing Basic Packages : Start
# INFO:Details:Import : re
# INFO:Details:Import : os
# INFO:Details:Import : sys
# INFO:Phases:Importing Basic Packages : End

# %%
# ==============================================================================
# Importing Project Specific Packages
# ==============================================================================

phases_logger.info('Importing Project Specific Packages : Start')

# Identifying Customer Targets (Python)
details_logger.info('Import : inline')
# %matplotlib inline

# import packages for text processing and machine learning
details_logger.info('Import : pandas')
import pandas as pd  # DataFrame structure and operations
from pandas.plotting import scatter_matrix  # scatter plot matrix

details_logger.info('Import : numpy')
import numpy as np  # arrays and numerical processing
import matplotlib.pyplot as plt  # 2D plotting

details_logger.info('Import : scipy')
from scipy.stats import uniform  # for training-and-test split

details_logger.info('Import : patsy')
import patsy  # translate model specification into design matrices

details_logger.info('Import : seaborn')
import seaborn as sns  # PROVIDES TRELLIS AND SMALL MULTIPLE PLOTTING

# import user-defined module
# details_logger.info('import evaluate_classifier')
# import evaluate_classifier as eval

# FOLLOWING PACKAGE BEST IMPORTED AND INSTALLED VIA CONDA PROMPT
# conda install -c conda-forge mlxtend

# Association Rules Mining
# details_logger.info('import mlxtend')
# from mlxtend.frequent_patterns import apriori            # EASY ASSOCIATION RULES PACKAGE FROM RABST
# from mlxtend.frequent_patterns import association_rules

details_logger.info('Import : queue')
from queue import Queue

details_logger.info('Import : threading')
import threading

details_logger.info('Import : time')
import time

details_logger.info('Import : sklearn')
from sklearn.tree import DecisionTreeRegressor  # machine learning tree
from sklearn.ensemble import RandomForestRegressor # ensemble method
from sklearn.metrics import mean_squared_error

details_logger.info('Import : statsmodels')
import statsmodels.api as sm  # logistic regression
import statsmodels.formula.api as smf  # R-like model specification
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf

details_logger.info('Import : pmdarima')
import pmdarima as pm

details_logger.info('Import : zipfile')
import zipfile

# Richie: Add your required imports of library here
details_logger.info('Import : tensorflow')
import tensorflow as tf
from keras.layers import LSTM, Dense
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from tensorflow import keras
from tensorflow.keras import layers
from keras.preprocessing.sequence import TimeseriesGenerator



phases_logger.info('Project Specific Package Load : End')
# Out:
# INFO:Phases:Importing Project Specific Packages : Start
# INFO:Details:Import : inline
# INFO:Details:Import : pandas
# INFO:Details:Import : numpy
# INFO:Details:Import : scipy
# INFO:Details:Import : patsy
# INFO:Details:Import : seaborn
# INFO:Details:Import : queue
# INFO:Details:Import : threading
# INFO:Details:Import : time
# INFO:Details:Import : sklearn
# INFO:Details:Import : statsmodels
# INFO:Details:Import : pmdarima
# INFO:Details:Import : zipfile
# INFO:Details:Import : tensorflow
# INFO:Phases:Project Specific Package Load : End

# %%
# ==============================================================================
# Present Working Directory
# ==============================================================================

# This will print the current directory : Debugging purposes
details_logger.info('PWD: ' + os.getcwd())
PWD = os.getcwd()
# Out:
# INFO:Details:PWD: /Users/richie/IST718/devel_001/predictingstockprice

# %%
# ==============================================================================
# Information
# ==============================================================================

# ------------------------------------------------------------------------------
# Following should be your tree such that the link 'stock_market_data' points to
# actual directory 'stock_market_data' that is 2 directories above

# 
# MY_PROJECT_DIR
# ├── BITBUCKET_CHECKOUT_DIR_000
# │   └── predictingstockprice
# │       ├── OtherTSVs
# │       ├── lib
# │       ├── stock_market_data -> ../../stock_market_data
# │       └── CSV -> ../../CSV
# ├── stock_market_data
# │   ├── forbes2000
# │   │   ├── csv
# │   │   └── json
# │   ├── nasdaq
# │   │   ├── csv
# │   │   └── json
# │   ├── nyse
# │   │   ├── csv
# │   │   └── json
# │   └── sp500
# │       ├── csv
# │       └── json
# └── CSV
#     ├── AdjustedClose_df.csv.zip
#     ├── Close_df.csv.zip
#     ├── High_df.csv.zip
#     ├── Low_df.csv.zip
#     └── Open_df.csv.zip
# 

# ------------------------------------------------------------------------------

# %%
# ==============================================================================
# User Settings
# ==============================================================================

phases_logger.info('User Settings : Start')

# Logging User Settings:
#
details_logger.info('User Settings:')


## Uncomment following to override the stock_market_data_path

# USER_SETTING_HERE
# 
# If the tree structure thing does not work for you, you may have to use the following paths instead:
## Ayush:
# stock_market_data_path = 'Add_your_path_here'
## CB:
# stock_market_data_path = '/Users/cbgarrett/Documents/ist718project/stock_market_data'
## Richard:
# stock_market_data_path = 'Add_your_path_here'
## Niranjan:
# stock_market_data_path = '/Users/niranjanjuvekar/MyStuff/Education_Niranjan/Data_Science_Syracuse_University/12_IST_718/Project/stock_market_data'



# USER_SETTING_HERE
# Select the dataFrame(s) to be used
# 
USE_Low_df           = False
USE_Open_df          = False
USE_Volume_df        = False
USE_High_df          = True
USE_Close_df         = True
USE_AdjustedClose_df = False


# USER_SETTING_HERE
# Variable breakAtIteration to be used for debugging purposes
# if breakAtIteration = 0 : goes through all files
#
breakAtIteration = 0

    
# USER_SETTING_HERE
# Once the dataFrame has been processed, we can
# write it to the disk in TSV or CSV format
#
write_CSV = False
write_TSV = False


# USER_SETTINGS_HERE
# Maximum number of parallel threads to be spawned
#
# maxThreads = 2
maxThreads = 6


# USER_SETTING_HERE
# Number of models to be run
#
# N = df.shape[1]-2
# N = 410
# N = 200
N = 100
# N = 50
# N = 10
# N = 1 # Run only one model (Default)


# USER_SETTINGS_HERE
# Number of forecasting periods (Unit : Business days)
#
n_periods = 30  


# USER_SETTING_HERE
# Last date with sampled values beyond which the dataFrame / CSV would be empty
LastSampledDate = '24/10/2022'


# USER_SETTING_HERE
# Output Dir
outputDir = 'Output'

# ------------------------------------------------------------------------------
# Processing and Logging the User Settings
# 


# Using stock_market_data link in the current directory
# stock_market_data -> ../../stock_market_data
#
stock_market_data_path = os.path.realpath('stock_market_data')
details_logger.info('User Setting : stock_market_data_path = ' + stock_market_data_path)


dfFileList = []

if USE_Low_df:
    details_logger.info('User Setting : USE_Low_df = True')
    dfFileList.append('Low')
if USE_Open_df:
    details_logger.info('User Setting : USE_Open_df = True')
    dfFileList.append('Open')
if USE_Volume_df:
    details_logger.info('User Setting : USE_Volume_df = True')
    dfFileList.append('Volume')
if USE_High_df:
    details_logger.info('User Setting : USE_High_df = True')
    dfFileList.append('High')
if USE_Close_df:
    details_logger.info('User Setting : USE_Close_df = True')
    dfFileList.append('Close')
if USE_AdjustedClose_df:
    details_logger.info('User Setting : USE_AdjustedClose_df = True')
    dfFileList.append('AdjustedClose')
if len(dfFileList) == 0:
    details_logger.info('Please select at least one dataFrame to operate on')
    details_logger.info('Set one of these to True in the user settings:')
    details_logger.info('USE_Low_df / USE_Open_df / USE_Volume_df / USE_High_df / USE_Close_df / USE_AdjustedClose_df')
    print('Dataframe(s) not specified. See details log for the error')
    exit(1)


if breakAtIteration == 0:
    details_logger.info('User Setting : breakAtIteration = 0 : Do not break')
else:
    details_logger.info('User Setting : breakAtIteration = ' + str(breakAtIteration))


details_logger.info('User Setting : Number of models to be run = ' + str(N))
    
    
details_logger.info('User Setting : write_CSV = ' + str(write_CSV))
details_logger.info('User Setting : write_TSV = ' + str(write_TSV))


details_logger.info('User Setting : Last sampled date = ' + LastSampledDate)



details_logger.info('User Settings : Number of models  = ' + str(N))
details_logger.info('User Settings : Maximum Threads   = ' + str(maxThreads))
details_logger.info('User Settings : Forecast Samples  = ' + str(n_periods))



phases_logger.info('User Settings : End')
# Out:
# INFO:Phases:User Settings : Start
# INFO:Details:User Settings:
# INFO:Details:User Setting : stock_market_data_path = /Users/richie/IST718/stock_market_data
# INFO:Details:User Setting : USE_High_df = True
# INFO:Details:User Setting : USE_Close_df = True
# INFO:Details:User Setting : breakAtIteration = 0 : Do not break
# INFO:Details:User Setting : Number of models to be run = 100
# INFO:Details:User Setting : write_CSV = False
# INFO:Details:User Setting : write_TSV = False
# INFO:Details:User Setting : Last sampled date = 24/10/2022
# INFO:Details:User Settings : Number of models  = 100
# INFO:Details:User Settings : Maximum Threads   = 6
# INFO:Details:User Settings : Forecast Samples  = 30
# INFO:Phases:User Settings : End

# %%
# ==============================================================================
# Unzip required dataFrame files
# ==============================================================================

for file in dfFileList:
    with zipfile.ZipFile(PWD+'/CSV/'+file+'_df.csv.zip', 'r') as zip_ref:
        zip_ref.extractall(PWD+'/CSV/')

# %%
# ==============================================================================
# Reading the dataFrames
# ==============================================================================

if 'Low' in dfFileList:
    LowDF_tickerSymbols = pd.read_csv(PWD+'/CSV/Low_df.csv', sep=',', header='infer')
    LowDF_tickerSymbols['Date'] = LowDF_tickerSymbols['Date'].str.replace('-','/')
    # pd.to_datetime(LowDF_tickerSymbols['Date'], infer_datetime_format=True)
    LowDF_tickerSymbols = LowDF_tickerSymbols.set_index('Date')
    LowDF_tickerSymbols = LowDF_tickerSymbols.loc[:LastSampledDate]
    LowDF_tickerSymbols = LowDF_tickerSymbols.fillna(method='ffill')
    
if 'Open' in dfFileList:
    OpenDF_tickerSymbols = pd.read_csv(PWD+'/CSV/Open_df.csv', sep=',', header='infer')
    OpenDF_tickerSymbols['Date'] = OpenDF_tickerSymbols['Date'].str.replace('-','/')
    # pd.to_datetime(OpenDF_tickerSymbols['Date'], infer_datetime_format=True)
    OpenDF_tickerSymbols = OpenDF_tickerSymbols.set_index('Date')
    OpenDF_tickerSymbols = OpenDF_tickerSymbols.loc[:LastSampledDate]
    OpenDF_tickerSymbols = OpenDF_tickerSymbols.fillna(method='ffill')

if 'Volume' in dfFileList:
    VolumeDF_tickerSymbols = pd.read_csv(PWD+'/CSV/Volume_df.csv', sep=',', header='infer')
    VolumeDF_tickerSymbols['Date'] = VolumeDF_tickerSymbols['Date'].str.replace('-','/')
    # pd.to_datetime(VolumeDF_tickerSymbols['Date'], infer_datetime_format=True)
    VolumeDF_tickerSymbols = VolumeDF_tickerSymbols.set_index('Date')
    VolumeDF_tickerSymbols = VolumeDF_tickerSymbols.loc[:LastSampledDate]
    VolumeDF_tickerSymbols = VolumeDF_tickerSymbols.fillna(method='ffill')

if 'High' in dfFileList:
    HighDF_tickerSymbols = pd.read_csv(PWD+'/CSV/High_df.csv', sep=',', header='infer')
    HighDF_tickerSymbols['Date'] = HighDF_tickerSymbols['Date'].str.replace('-','/')
    # pd.to_datetime(HighDF_tickerSymbols['Date'], infer_datetime_format=True)
    HighDF_tickerSymbols = HighDF_tickerSymbols.set_index('Date')
    HighDF_tickerSymbols = HighDF_tickerSymbols.loc[:LastSampledDate]
    HighDF_tickerSymbols = HighDF_tickerSymbols.fillna(method='ffill')

if 'Close' in dfFileList:
    CloseDF_tickerSymbols = pd.read_csv(PWD+'/CSV/Close_df.csv', sep=',', header='infer')
    CloseDF_tickerSymbols['Date'] = CloseDF_tickerSymbols['Date'].str.replace('-','/')
    # pd.to_datetime(CloseDF_tickerSymbols['Date'], infer_datetime_format=True)
    CloseDF_tickerSymbols = CloseDF_tickerSymbols.set_index('Date')
    CloseDF_tickerSymbols = CloseDF_tickerSymbols.loc[:LastSampledDate]
    CloseDF_tickerSymbols = CloseDF_tickerSymbols.fillna(method='ffill')

if 'AdjustedClose' in dfFileList:
    AdjustedCloseDF_tickerSymbols = pd.read_csv(PWD+'/CSV/AdjustedClose_df.csv', sep=',', header='infer')
    AdjustedCloseDF_tickerSymbols['Date'] = AdjustedCloseDF_tickerSymbols['Date'].str.replace('-','/')
    # pd.to_datetime(AdjustedCloseDF_tickerSymbols['Date'], infer_datetime_format=True)
    AdjustedCloseDF_tickerSymbols = AdjustedCloseDF_tickerSymbols.set_index('Date')
    AdjustedCloseDF_tickerSymbols = AdjustedCloseDF_tickerSymbols.loc[:LastSampledDate]
    AdjustedCloseDF_tickerSymbols = AdjustedCloseDF_tickerSymbols.fillna(method='ffill')

# %%
OpenDF_tickerSymbols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/p_/490p278j7v5drvd21qm3zn6r0000gn/T/ipykernel_42806/151539468.py in <module>
# ----> 1 OpenDF_tickerSymbols
#
# NameError: name 'OpenDF_tickerSymbols' is not defined

# %%
# ==============================================================================
# dropNan function to drop empty rows from given dataFrame
# ==============================================================================

def dropNan (df):
    ignoreColumns = ['Unnamed: 0', 'Date', 'WeekDay']
    columns = df.columns
    # print(columns)
    for i in columns:
        if i not in ignoreColumns:
            # print('i = ', i)
            df = df[df[i].notna()]
    # print(df)
    return(df)

'''
# Example:
mydf = dropNan(MYDF[['CSCO', 'SBUX']])
print(mydf)
'''
# Out:
# "\n# Example:\nmydf = dropNan(MYDF[['CSCO', 'SBUX']])\nprint(mydf)\n"

# %%
# ==============================================================================
# Initialize variables for model generation
# ==============================================================================

phases_logger.info('Initialize for Models Generation : Start')

# Threads Dictionary
t = {}

# Queue Settings
q = Queue(maxsize = maxThreads)

# Model Dictionary
model = {}

nan_value = float("NaN")


# Model Generation Tracker : Keeps track of what models are built and being built
modelGenTracker = []
modelGenPointer = len(modelGenTracker) - 1


phases_logger.info('Initialize for Models Generation : End')
# Out:
# INFO:Phases:Initialize for Models Generation : Start
# INFO:Phases:Initialize for Models Generation : End

# %%
# ==============================================================================
# Model-Specific : Initialize Dictionaries
# ==============================================================================

phases_logger.info('Initialize Dictionaries : Start')

RNN_models_dict = {}
RNN_forecast_dict = {}
RNN_model_residuals_dict = {}

phases_logger.info('Initialize Dictionaries : End')
# Out:
# INFO:Phases:Initialize Dictionaries : Start
# INFO:Phases:Initialize Dictionaries : End

# %%
phases_logger.info('Create Model Definition : Start')

def createModel_RNN(modelNumber):
    
    tickerSymbol = MYDF.columns[modelNumber]
    print('Model number : ', modelNumber, ' :: Ticker Symbol : ', tickerSymbol)
    details_logger.info('Model number : ' + str(modelNumber) + ' :: Ticker Symbol : ' + tickerSymbol)

    mydf = MYDF[tickerSymbol].to_frame()
    mydf.replace("", nan_value, inplace=True)
    mydf.dropna(inplace=True)

    data = mydf[tickerSymbol].values
    data = data.reshape((-1,1))

    split_percent = 0.80
    split = int(split_percent*len(data))

    X_train = data[:split]
    X_test  = data[split:]

    date_train = mydf.index.values[:split]
    date_test = mydf.index.values[split:]


    look_back = 15

    train_generator = TimeseriesGenerator(X_train, X_train, length=look_back, batch_size=20)     
    test_generator = TimeseriesGenerator(X_test, X_test, length=look_back, batch_size=1)


    model = Sequential()
    model.add(
        SimpleRNN(10,
            activation='relu',
            input_shape=(look_back,1))
    )
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    num_epochs = RNN_EPOCHS = 10
    model.fit_generator(train_generator, epochs=num_epochs, verbose=1)



    data = data.reshape((-1))

    def predict(num_prediction, model):
        prediction_list = data[-look_back:]

        for _ in range(num_prediction):
            x = prediction_list[-look_back:]
            x = x.reshape((1, look_back, 1))
            out = model.predict(x)[0][0]
            prediction_list = np.append(prediction_list, out)
        prediction_list = prediction_list[look_back-1:]

        return prediction_list

    def predict_dates(num_prediction):
        last_date = mydf.index.values[-1]
        prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
        return prediction_dates

    num_prediction = 30
    forecast = predict(num_prediction, model)
    forecast_dates = predict_dates(num_prediction)
    RNN_forecast_dict[tickerSymbol] = forecast


    q.get()
    details_logger.info('Thread Spawn : ' + str(modelNumber) + ' : Done')

    modelGenTracker.append(modelNumber)

    
phases_logger.info('Create Model Definition : End')
# Out:
# INFO:Phases:Create Model Definition : Start
# INFO:Phases:Create Model Definition : End

# %%
# ==============================================================================
# Running Threads : Making Models in Threads
# ==============================================================================

phases_logger.info('Making Models in Threads : Start')
details_logger.info('Making Models in Threads')

for file in dfFileList:

    details_logger.info('Running Threads : File : ' + file + ' : Start')
    modelGenTracker = []
    modelGenPointer = len(modelGenTracker) - 1
    
    if file == 'Low':
        MYDF = LowDF_tickerSymbols.iloc[:, 2:]
    if file == 'Open':
        MYDF = OpenDF_tickerSymbols.iloc[:, 2:]
    if file == 'Volume':
        MYDF = VolumeDF_tickerSymbols.iloc[:, 2:]
    if file == 'High':
        MYDF = HighDF_tickerSymbols.iloc[:, 2:]
    if file == 'Close':
        MYDF = CloseDF_tickerSymbols.iloc[:, 2:]
    if file == 'AdjustedClose':
        MYDF = AdjustedCloseDF_tickerSymbols.iloc[:, 2:]

    for modelNumber in range(0,N,1):
        details_logger.info('Thread Spawn : ' + str(modelNumber) + ' : Starting')
        while(q.full()):
            # print('Sleeping 1 sec')
            details_logger.info('Sleeping 1 sec')
            time.sleep(1)


        if modelGenPointer < len(modelGenTracker) - 1:
            for i in range (modelGenPointer, len(modelGenTracker), 1):
                details_logger.info('Thread Join : ' + str(modelGenTracker[i]))
                t[modelGenTracker[i]].join()
                #clear_output(wait=False)
            modelGenPointer = len(modelGenTracker) - 1


        # Creating Threads
        details_logger.info('t[modelNumber] = ' + str(modelNumber))
        t[modelNumber] = threading.Thread(target=createModel_RNN, args=(modelNumber,))


        # Running the thread
        details_logger.info('Q : put' + str(modelNumber))
        q.put(modelNumber)
        t[modelNumber].start()

#     time.sleep(100) TESTING THIS 

    while (len(modelGenTracker) < N):
        if modelGenPointer < len(modelGenTracker) - 1:
            for i in range (modelGenPointer, len(modelGenTracker), 1):
                details_logger.info('Thread Join : ' + str(modelGenTracker[i]))
                t[modelGenTracker[i]].join()
                #clear_output(wait=False)
            modelGenPointer = len(modelGenTracker) - 1
        
        # For debugging:
        # print('modelGenTracker : ', modelGenTracker) # HERE
        # print('modelGenPointer : ', modelGenPointer) # HERE

        time.sleep(1)

    RNN_forecast_df = pd.DataFrame.from_dict(RNN_forecast_dict, orient='index')
    RNN_forecast_df.to_csv(outputDir+'/'+'RNN_forecast_'+file+'df.csv', sep='\t', encoding='utf-8')

    details_logger.info('Running Threads : File : ' + file + ' : End')
    
#clear_output(wait=False)

phases_logger.info('Making Models in Threads : End')
# Out:
# INFO:Phases:Making Models in Threads : Start
# INFO:Details:Making Models in Threads
# INFO:Details:Running Threads : File : High : Start
# INFO:Details:Thread Spawn : 0 : Starting
# INFO:Details:t[modelNumber] = 0
# INFO:Details:Q : put0
# INFO:Details:Model number : 0 :: Ticker Symbol : CSCO
# INFO:Details:Thread Spawn : 1 : Starting
# INFO:Details:t[modelNumber] = 1
# 2022-12-19 13:17:22.610305: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:Details:Q : put1
# INFO:Details:Thread Spawn : 2 : Starting
# INFO:Details:Model number : 1 :: Ticker Symbol : UAL
# INFO:Details:t[modelNumber] = 2
# INFO:Details:Q : put2
# INFO:Details:Model number : 2 :: Ticker Symbol : TROW
# INFO:Details:Thread Spawn : 3 : Starting
# INFO:Details:t[modelNumber] = 3
# INFO:Details:Q : put3
# INFO:Details:Model number : 3 :: Ticker Symbol : ISRG
# INFO:Details:Thread Spawn : 4 : Starting
# INFO:Details:t[modelNumber] = 4
# INFO:Details:Q : put4
# INFO:Details:Thread Spawn : 5 : Starting
# INFO:Details:Model number : 4 :: Ticker Symbol : NVR
# INFO:Details:t[modelNumber] = 5
# INFO:Details:Q : put5
# INFO:Details:Thread Spawn : 6 : Starting
# INFO:Details:Model number : 5 :: Ticker Symbol : MRO
# INFO:Details:Sleeping 1 sec
# Model number :  0  :: Ticker Symbol :  CSCO
# Model number :  1  :: Ticker Symbol :  UAL
# Model number :  2  :: Ticker Symbol :  TROW
# Model number :  3  :: Ticker Symbol :  ISRG
# Model number :  4  :: Ticker Symbol :  NVR
# Model number :  5  :: Ticker Symbol :  MRO
# /var/folders/p_/490p278j7v5drvd21qm3zn6r0000gn/T/ipykernel_42806/700060405.py:42: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator, epochs=num_epochs, verbose=1)
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# INFO:Details:Sleeping 1 sec
# INFO:Details:Sleeping 1 sec
# 201/326 [=================>............] - ETA: 0s - loss: 1717.6985
# INFO:Details:Sleeping 1 sec
# 244/244 [==============================] - 3s 5ms/step - loss: 3444.4031
# 249/544 [============>.................] - ETA: 1s - loss: 136294.4062Epoch 2/10
# 326/326 [==============================] - 4s 5ms/step - loss: 1498.0864
# 286/477 [================>.............] - ETA: 1s - loss: 63.8792Epoch 2/10
# 412/534 [======================>.......] - ETA: 0s - loss: 4.24265
# INFO:Details:Sleeping 1 sec
# 244/244 [==============================] - 1s 5ms/step - loss: 602.2516
# 421/771 [===============>..............] - ETA: 1s - loss: 0.48076Epoch 3/10
# 477/477 [==============================] - 4s 5ms/step - loss: 38.4305
# 532/534 [============================>.] - ETA: 0s - loss: 3.7909Epoch 2/10
# 534/534 [==============================] - 5s 5ms/step - loss: 3.7821
#   1/477 [..............................] - ETA: 7s - loss: 0.88648125Epoch 2/10
# 544/544 [==============================] - 4s 5ms/step - loss: 69095.2969
#  14/534 [..............................] - ETA: 2s - loss: 1.3191 Epoch 2/10
# 271/326 [=======================>......] - ETA: 0s - loss: 414.7741
# INFO:Details:Sleeping 1 sec
# 326/326 [==============================] - 2s 5ms/step - loss: 345.0195
# 116/544 [=====>........................] - ETA: 2s - loss: 54.1302Epoch 3/10
# 244/244 [==============================] - 1s 5ms/step - loss: 1.3876
# 211/477 [============>.................] - ETA: 1s - loss: 0.4330Epoch 4/10
#  63/244 [======>.......................] - ETA: 0s - loss: 1.4544
# INFO:Details:Sleeping 1 sec
# 771/771 [==============================] - 6s 5ms/step - loss: 0.3090
# 190/326 [================>.............] - ETA: 0s - loss: 1.2412Epoch 2/10
# 440/534 [=======================>......] - ETA: 0s - loss: 2.4662
# INFO:Details:Sleeping 1 sec
# 326/326 [==============================] - 2s 5ms/step - loss: 1.0743
# 244/244 [==============================] - 1s 6ms/step - loss: 1.3919
# 464/477 [============================>.] - ETA: 0s - loss: 0.3940Epoch 4/10
# 462/534 [========================>.....] - ETA: 0s - loss: 2.4162Epoch 5/10
# 477/477 [==============================] - 3s 5ms/step - loss: 0.4130
# 473/534 [=========================>....] - ETA: 0s - loss: 2.3880Epoch 3/10
# 534/534 [==============================] - 3s 5ms/step - loss: 2.2608
#  51/477 [==>...........................] - ETA: 2s - loss: 0.2190Epoch 3/10
# 544/544 [==============================] - 3s 5ms/step - loss: 71.2121
#  38/534 [=>............................] - ETA: 2s - loss: 2.5318Epoch 3/10
# 200/326 [=================>............] - ETA: 0s - loss: 0.8244
# INFO:Details:Sleeping 1 sec
# 244/244 [==============================] - 1s 4ms/step - loss: 1.3772
# 363/771 [=============>................] - ETA: 2s - loss: 0.09957Epoch 6/10
# 326/326 [==============================] - 1s 5ms/step - loss: 0.7543
# 218/544 [===========>..................] - ETA: 1s - loss: 82.9341Epoch 5/10
# 324/544 [================>.............] - ETA: 0s - loss: 76.2851
# INFO:Details:Sleeping 1 sec
# 244/244 [==============================] - 1s 5ms/step - loss: 1.3585
# 616/771 [======================>.......] - ETA: 0s - loss: 0.0966Epoch 7/10
# 477/477 [==============================] - 2s 5ms/step - loss: 0.3815
# 446/534 [========================>.....] - ETA: 0s - loss: 1.4634Epoch 4/10
# 534/534 [==============================] - 2s 4ms/step - loss: 1.3404
# 268/326 [=======================>......] - ETA: 0s - loss: 0.8346Epoch 4/10
# 326/326 [==============================] - 1s 4ms/step - loss: 0.7608
# 544/544 [==============================] - 2s 4ms/step - loss: 69.4355
# 771/771 [==============================] - 4s 5ms/step - loss: 0.1012
# Epoch 6/10
# Epoch 4/10
# Epoch 3/10
#   1/771 [..............................] - ETA: 20s - loss: 0.0736
# INFO:Details:Sleeping 1 sec
# 244/244 [==============================] - 1s 4ms/step - loss: 1.3565
#  96/771 [==>...........................] - ETA: 2s - loss: 0.0963Epoch 8/10
# 119/244 [=============>................] - ETA: 0s - loss: 1.2281
# INFO:Details:Sleeping 1 sec
# 326/326 [==============================] - 1s 5ms/step - loss: 1.0558
# 331/771 [===========>..................] - ETA: 1s - loss: 0.0987Epoch 7/10
# 477/477 [==============================] - 2s 5ms/step - loss: 0.3840
# 244/244 [==============================] - 1s 4ms/step - loss: 1.3327
# 346/771 [============>.................] - ETA: 1s - loss: 0.0976Epoch 9/10
# Epoch 5/10
# 450/544 [=======================>......] - ETA: 0s - loss: 66.0907
# INFO:Details:Sleeping 1 sec
# 534/534 [==============================] - 3s 5ms/step - loss: 1.3693
# Epoch 5/10
# 544/544 [==============================] - 2s 5ms/step - loss: 69.1732
# Epoch 5/10
# 244/244 [==============================] - 1s 4ms/step - loss: 1.3249
#  25/544 [>.............................] - ETA: 2s - loss: 68.2576Epoch 10/10
# 326/326 [==============================] - 1s 5ms/step - loss: 0.7243
#  89/244 [=========>....................] - ETA: 0s - loss: 1.2735Epoch 8/10
# 101/244 [===========>..................] - ETA: 0s - loss: 1.3505
# INFO:Details:Sleeping 1 sec
# 771/771 [==============================] - 3s 4ms/step - loss: 0.0943
# 250/534 [=============>................] - ETA: 1s - loss: 1.1452Epoch 4/10
# 477/477 [==============================] - 2s 4ms/step - loss: 0.3780
# Epoch 6/10
# 244/244 [==============================] - 1s 4ms/step - loss: 1.3072
# 1/1 [==============================] - 0s 301ms/step loss: 0.45
# 231/326 [====================>.........] - ETA: 0s - loss: 0.6571
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 25ms/step- loss: 67.64
# 1/1 [==============================] - 0s 19ms/step- loss: 67.09
# 1/1 [==============================] - 0s 45ms/step- loss: 0.36
# 1/1 [==============================] - 0s 46ms/step- loss: 69.58
# 1/1 [==============================] - 0s 63ms/step- loss: 0.72
# 326/326 [==============================] - 2s 6ms/step - loss: 0.7238
# 238/771 [========>.....................] - ETA: 3s - loss: 0.1058Epoch 9/10
#   3/326 [..............................] - ETA: 18s - loss: 0.5346
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 71ms/step- loss: 0.38
# 1/1 [==============================] - 0s 26ms/step- loss: 67.63
# 534/534 [==============================] - 3s 6ms/step - loss: 0.9814
# Epoch 6/10
# 1/1 [==============================] - 0s 39ms/step- loss: 0.34
# 1/1 [==============================] - 0s 29ms/step- loss: 0.102
# 1/1 [==============================] - 0s 34ms/step- loss: 69.36
# 544/544 [==============================] - 3s 6ms/step - loss: 68.6524
# 119/326 [=========>....................] - ETA: 1s - loss: 0.6672Epoch 6/10
# 1/1 [==============================] - 0s 27ms/step- loss: 0.31
# 1/1 [==============================] - 0s 31ms/step- loss: 0.10
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 28ms/step- loss: 2.26
# 1/1 [==============================] - 0s 29ms/step- loss: 77.87
# 1/1 [==============================] - 0s 30ms/step- loss: 0.66
# 1/1 [==============================] - 0s 24ms/step- loss: 82.36
# 1/1 [==============================] - 0s 79ms/step- loss: 0.10
# 1/1 [==============================] - 0s 41ms/step- loss: 80.61
# 477/477 [==============================] - 3s 7ms/step - loss: 0.3940
# 539/771 [===================>..........] - ETA: 1s - loss: 0.0979Epoch 7/10
# 1/1 [==============================] - 0s 28ms/step - loss: 0.37
# 556/771 [====================>.........] - ETA: 1s - loss: 0.0956
# INFO:Details:Sleeping 1 sec
# 326/326 [==============================] - 2s 7ms/step - loss: 0.6885
#  17/477 [>.............................] - ETA: 3s - loss: 0.6144Epoch 10/10
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step- loss: 0.43
# 1/1 [==============================] - 0s 24ms/step- loss: 0.71
# 1/1 [==============================] - 0s 27ms/step- loss: 1.223
# 1/1 [==============================] - 0s 23ms/step- loss: 0.70
# 1/1 [==============================] - 0s 19ms/step- loss: 68.06
# 1/1 [==============================] - 0s 23ms/step- loss: 67.01
# 1/1 [==============================] - 0s 24ms/step- loss: 0.56
# 1/1 [==============================] - 0s 24ms/step- loss: 66.75
# 1/1 [==============================] - 0s 21ms/step- loss: 65.40
# INFO:Details:Thread Spawn : 1 : Done
# 771/771 [==============================] - 5s 6ms/step - loss: 0.1003
# 401/544 [=====================>........] - ETA: 0s - loss: 64.1019Epoch 5/10
# INFO:Details:Thread Join : 1
#   1/771 [..............................] - ETA: 15s - loss: 0.0709
# INFO:Details:Thread Join : 1
# INFO:Details:t[modelNumber] = 6
# INFO:Details:Q : put6
# 507/534 [===========================>..] - ETA: 0s - loss: 1.1902Model number :
# INFO:Details:Model number : 6 :: Ticker Symbol : BA
# INFO:Details:Thread Spawn : 7 : Starting
#  6  :: Ticker Symbol :  BA
# 199/326 [=================>............] - ETA: 0s - loss: 0.6036
# INFO:Details:Sleeping 1 sec
# 534/534 [==============================] - 3s 5ms/step - loss: 1.1646
# Epoch 7/10
#  73/771 [=>............................] - ETA: 3s - loss: 0.0974Epoch 1/10
# 544/544 [==============================] - 3s 5ms/step - loss: 68.8892
# 136/771 [====>.........................] - ETA: 2s - loss: 0.0799Epoch 7/10
# 326/326 [==============================] - 2s 5ms/step - loss: 0.6325
# 1/1 [==============================] - 0s 261ms/step loss: 0.08
# 455/477 [===========================>..] - ETA: 0s - loss: 0.3950
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 29ms/step- loss: 0.08
# 477/477 [==============================] - 2s 5ms/step - loss: 0.4062
# Epoch 8/10
# 1/1 [==============================] - 0s 19ms/step- loss: 0.735
# 1/1 [==============================] - 0s 22ms/step- loss: 0.08
# 1/1 [==============================] - 0s 26ms/step- loss: 0.08
# 1/1 [==============================] - 0s 27ms/step- loss: 0.09
# 1/1 [==============================] - 0s 20ms/step- loss: 0.72
# 1/1 [==============================] - 0s 18ms/step- loss: 0.09
# 1/1 [==============================] - 0s 33ms/step- loss: 0.77
# 1/1 [==============================] - 0s 28ms/step- loss: 0.37
# 1/1 [==============================] - 0s 18ms/step15 - loss: 554.92
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 19ms/step- loss: 72.572
# 1/1 [==============================] - 0s 19ms/step- loss: 72.02
# 1/1 [==============================] - 0s 22ms/step- loss: 73.50
# 1/1 [==============================] - 0s 20ms/step- loss: 0.0888
# 1/1 [==============================] - 0s 20ms/step- loss: 1.44
# 1/1 [==============================] - 0s 20ms/step- loss: 75.75
# 1/1 [==============================] - 0s 24ms/step- loss: 0.0862
# 534/534 [==============================] - 3s 5ms/step - loss: 1.4096
# 301/477 [=================>............] - ETA: 0s - loss: 0.3683Epoch 8/10
# 1/1 [==============================] - 0s 25ms/step- loss: 2090.75
# 1/1 [==============================] - 0s 20ms/step- loss: 0.0924
# 1/1 [==============================] - 0s 21ms/step- loss: 71.12
#  70/534 [==>...........................] - ETA: 2s - loss: 1.29435
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 17ms/step- loss: 71.88
# 1/1 [==============================] - 0s 22ms/step- loss: 0.0931
# 1/1 [==============================] - 0s 23ms/step- loss: 70.76
# 544/544 [==============================] - 3s 5ms/step - loss: 70.1165
# Epoch 8/10
# 1/1 [==============================] - 0s 17ms/step - loss: 119.03
# 1/1 [==============================] - 0s 17ms/step- loss: 0.92.155
# 477/477 [==============================] - 2s 5ms/step - loss: 0.3671
#  34/544 [>.............................] - ETA: 2s - loss: 54.1620Epoch 9/10
# 1/1 [==============================] - 0s 27ms/step- loss: 0.92
# 1/1 [==============================] - 0s 19ms/step- loss: 49.55
# 771/771 [==============================] - 4s 5ms/step - loss: 0.0895
# 1/1 [==============================] - 0s 15ms/step
# Epoch 6/10
# 1/1 [==============================] - 0s 23ms/step- loss: 0.161
# 230/534 [===========>..................] - ETA: 1s - loss: 0.9148
# INFO:Details:Thread Spawn : 3 : Done
#  84/771 [==>...........................] - ETA: 2s - loss: 0.0827
# INFO:Details:Thread Join : 1
# INFO:Details:Thread Join : 3
# 298/534 [===============>..............] - ETA: 1s - loss: 0.84384
# INFO:Details:t[modelNumber] = 7
# INFO:Details:Q : put7
# INFO:Details:Model number : 7 :: Ticker Symbol : GILD
# Model number :  7  :: Ticker Symbol :  GILD
# 187/544 [=========>....................] - ETA: 1s - loss: 50.8478
# INFO:Details:Thread Spawn : 8 : Starting
# INFO:Details:Sleeping 1 sec
# 242/544 [============>.................] - ETA: 1s - loss: 47.2143Epoch 1/10
# 378/544 [===================>..........] - ETA: 0s - loss: 67.2847
# INFO:Details:Sleeping 1 sec
# 534/534 [==============================] - 3s 5ms/step - loss: 0.7310
# 433/544 [======================>.......] - ETA: 0s - loss: 71.4454Epoch 9/10
#  27/534 [>.............................] - ETA: 26s - loss: 0.7370
# INFO:Details:Sleeping 1 sec
# 771/771 [==============================] - 6s 6ms/step - loss: 589.5680
# Epoch 2/10
# 477/477 [==============================] - 3s 7ms/step - loss: 0.3772
# 518/544 [===========================>..] - ETA: 0s - loss: 72.1930Epoch 10/10
# 544/544 [==============================] - 4s 7ms/step - loss: 72.0697
#  25/477 [>.............................] - ETA: 1s - loss: 0.8744Epoch 9/10
# 172/477 [=========>....................] - ETA: 1s - loss: 0.4510
# INFO:Details:Sleeping 1 sec
# 771/771 [==============================] - 5s 6ms/step - loss: 0.0801
# 192/449 [===========>..................] - ETA: 1s - loss: 1826.8434Epoch 7/10
# 386/544 [====================>.........] - ETA: 0s - loss: 77.5624
# INFO:Details:Sleeping 1 sec
# 534/534 [==============================] - 4s 7ms/step - loss: 0.6867
# 434/544 [======================>.......] - ETA: 0s - loss: 73.4385Epoch 10/10
# 477/477 [==============================] - 2s 4ms/step - loss: 0.3726
# 1/1 [==============================] - 0s 285ms/step loss: 72.64
# 544/544 [==============================] - 2s 4ms/step - loss: 71.7738
# 1/1 [==============================] - 0s 19ms/step- loss: 847.85
# 227/771 [=======>......................] - ETA: 2s - loss: 0.2201Epoch 10/10
# 1/1 [==============================] - 0s 22ms/step- loss: 0.51581
# 449/449 [==============================] - 5s 4ms/step - loss: 789.4762
# Epoch 2/10
# 1/1 [==============================] - 0s 32ms/step- loss: 72.06
# 283/771 [==========>...................] - ETA: 2s - loss: 0.1895
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step- loss: 0.56
# 1/1 [==============================] - 0s 16ms/step- loss: 0.68
# 1/1 [==============================] - 0s 17ms/step- loss: 0.70
# 1/1 [==============================] - 0s 19ms/step- loss: 0.17
# 771/771 [==============================] - 3s 4ms/step - loss: 0.5152
# 154/544 [=======>......................] - ETA: 1s - loss: 59.9413Epoch 3/10
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step- loss: 0.16
# 1/1 [==============================] - 0s 19ms/step- loss: 0.55
# 1/1 [==============================] - 0s 16ms/step- loss: 0.64
# 1/1 [==============================] - 0s 21ms/step- loss: 0.55
# 1/1 [==============================] - 0s 26ms/step- loss: 0.55
# 1/1 [==============================] - 0s 19ms/step- loss: 0.14
# 268/544 [=============>................] - ETA: 1s - loss: 67.3741
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 20ms/step- loss: 73.38
# 1/1 [==============================] - 0s 19ms/step- loss: 73.11
# 1/1 [==============================] - 0s 19ms/step- loss: 0.13
# 1/1 [==============================] - 0s 20ms/step- loss: 0.66
# 534/534 [==============================] - 2s 4ms/step - loss: 0.6605
# 1/1 [==============================] - 0s 26ms/step- loss: 68.42
# 1/1 [==============================] - 0s 22ms/step- loss: 1.53
# 1/1 [==============================] - 0s 26ms/step- loss: 0.52
# 449/449 [==============================] - 2s 4ms/step - loss: 1.4688
# 448/544 [=======================>......] - ETA: 0s - loss: 68.8579Epoch 3/10
# 1/1 [==============================] - 0s 299ms/step loss: 1.21
# 1/1 [==============================] - 0s 26ms/step- loss: 0.11
# 1/1 [==============================] - ETA: 0s: 1s - loss: 1.6209
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step- loss: 70.08
# 1/1 [==============================] - 0s 20ms/step- loss: 2.25
# 1/1 [==============================] - 0s 19ms/step- loss: 0.10
# 1/1 [==============================] - 0s 24ms/step- loss: 2.06
# 771/771 [==============================] - 4s 5ms/step - loss: 0.1081
# Epoch 8/10
# 1/1 [==============================] - 0s 18ms/step- loss: 71.04
# 1/1 [==============================] - 0s 20ms/step- loss: 0.52
# 1/1 [==============================] - 0s 18ms/step- loss: 0.022
# 544/544 [==============================] - 3s 5ms/step - loss: 73.8179
# 1/1 [==============================] - 0s 23ms/step- loss: 0.51
# 1/1 [==============================] - 0s 34ms/step- loss: 0.50
# 1/1 [==============================] - 0s 22ms/step- loss: 0.49
# INFO:Details:Thread Spawn : 0 : Done
# 1/1 [==============================] - 0s 20ms/step- loss: 0.48
# 1/1 [==============================] - 0s 18ms/step- loss: 1.624
# 1/1 [==============================] - 0s 223ms/step loss: 0.08
# 1/1 [==============================] - 0s 22ms/step- loss: 0.08
# 1/1 [==============================] - 0s 28ms/step- loss: 0.49
# 1/1 [==============================] - 0s 19ms/step- loss: 0.07
# 1/1 [==============================] - 0s 17ms/step- loss: 0.50
# 1/1 [==============================] - 0s 16ms/step- loss: 0.50
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step- loss: 0.51
# 1/1 [==============================] - 0s 22ms/step
# 279/449 [=================>............] - ETA: 0s - loss: 1.4331
# INFO:Details:Thread Join : 3
# 568/771 [=====================>........] - ETA: 0s - loss: 0.5099
# INFO:Details:Thread Join : 0
# INFO:Details:t[modelNumber] = 8
# INFO:Details:Q : put8
# Model number :  8  :: Ticker Symbol :  NLSN
# 291/449 [==================>...........] - ETA: 0s - loss: 1.3841
# INFO:Details:Model number : 8 :: Ticker Symbol : NLSN
# 205/771 [======>.......................] - ETA: 2s - loss: 0.0691
# INFO:Details:Thread Spawn : 9 : Starting
# 579/771 [=====================>........] - ETA: 0s - loss: 0.5109
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step- loss: 0.5104
# 1/1 [==============================] - 0s 21ms/step
# 235/771 [========>.....................] - ETA: 2s - loss: 0.0831Epoch 1/10
# 1/1 [==============================] - 0s 27ms/step- loss: 0.10
# 1/1 [==============================] - 0s 24ms/step- loss: 0.11
# 1/1 [==============================] - 0s 30ms/step- loss: 0.50
# 1/1 [==============================] - 0s 25ms/step- loss: 0.52
# 1/1 [==============================] - 0s 29ms/step- loss: 0.52
# 1/1 [==============================] - 0s 23ms/step- loss: 0.10
# 1/1 [==============================] - 0s 22ms/step- loss: 0.51
# 1/1 [==============================] - 0s 24ms/step- loss: 0.11
# 1/1 [==============================] - 0s 29ms/step- loss: 0.51
# 1/1 [==============================] - 0s 25ms/step- loss: 0.10
# 449/449 [==============================] - 2s 4ms/step - loss: 1.3837
# 358/771 [============>.................] - ETA: 1s - loss: 0.1071Epoch 4/10
# 1/1 [==============================] - 0s 26ms/step- loss: 0.51
# 1/1 [==============================] - 0s 21ms/step- loss: 0.10
# 1/1 [==============================] - 0s 28ms/step- loss: 0.524
# 1/1 [==============================] - 0s 22ms/step- loss: 0.10
# 1/1 [==============================] - 0s 20ms/step- loss: 6.48
# 398/771 [==============>...............] - ETA: 1s - loss: 0.1013
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 29ms/step- loss: 0.51
# 771/771 [==============================] - 4s 5ms/step - loss: 0.5127
# Epoch 4/10
# 1/1 [==============================] - 0s 22ms/step- loss: 0.10
# 1/1 [==============================] - 0s 29ms/step- loss: 3.137
# 1/1 [==============================] - 0s 18ms/step- loss: 0.09
# 1/1 [==============================] - 0s 21ms/step- loss: 0.09
# 1/1 [==============================] - 0s 20ms/step- loss: 0.31
# 1/1 [==============================] - 0s 21ms/step- loss: 0.35
# INFO:Details:Thread Spawn : 2 : Done
# 1/1 [==============================] - 0s 24ms/step- loss: 0.09
# 1/1 [==============================] - 0s 18ms/step- loss: 2.42
# 1/1 [==============================] - 0s 15ms/step- loss: 0.48
# 1/1 [==============================] - 0s 22ms/step- loss: 87.4590
# 1/1 [==============================] - 0s 16ms/step- loss: 0.48
# INFO:Details:Thread Join : 0
# INFO:Details:Thread Join : 2
# INFO:Details:t[modelNumber] = 9
#  43/171 [======>.......................] - ETA: 0s - loss: 35.0194
# INFO:Details:Q : put9
# INFO:Details:Thread Spawn : 10 : Starting
# Model number :  9  :: Ticker Symbol :  EQIX
# 228/771 [=======>......................] - ETA: 2s - loss: 0.5093
# INFO:Details:Model number : 9 :: Ticker Symbol : EQIX
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step- loss: 0.08
#  81/171 [=============>................] - ETA: 0s - loss: 19.3088Epoch 1/10
# 1/1 [==============================] - 0s 28ms/step- loss: 0.53
# 1/1 [==============================] - 0s 21ms/step- loss: 0.08
# 1/1 [==============================] - 0s 18ms/step- loss: 0.08
# 1/1 [==============================] - 0s 18ms/step- loss: 0.52
# 1/1 [==============================] - 0s 21ms/step- loss: 0.56
# 771/771 [==============================] - 4s 5ms/step - loss: 0.0796
# 403/449 [=========================>....] - ETA: 0s - loss: 2.2762Epoch 9/10
# 171/171 [==============================] - 3s 5ms/step - loss: 10.1584
# 350/771 [============>.................] - ETA: 1s - loss: 0.5604Epoch 2/10
# 1/1 [==============================] - 0s 29ms/step- loss: 1.18
# 1/1 [==============================] - 0s 20ms/step- loss: 2.36
# 449/449 [==============================] - 2s 5ms/step - loss: 2.2875
# 395/771 [==============>...............] - ETA: 1s - loss: 0.5356Epoch 5/10
# 1/1 [==============================] - 0s 18ms/step- loss: 0.03
# 1/1 [==============================] - 0s 21ms/step- loss: 0.52
#  25/449 [>.............................] - ETA: 1s - loss: 1.0507
# INFO:Details:Thread Spawn : 4 : Done
# 421/771 [===============>..............] - ETA: 1s - loss: 0.5169
# INFO:Details:Thread Join : 2
# INFO:Details:Thread Join : 4
#  37/449 [=>............................] - ETA: 1s - loss: 0.7923
# INFO:Details:t[modelNumber] = 10
# INFO:Details:Q : put10
# INFO:Details:Thread Spawn : 11 : Starting
# Model number :  10  :: Ticker Symbol :  MDT
#  84/171 [=============>................] - ETA: 0s - loss: 3.6540
# INFO:Details:Model number : 10 :: Ticker Symbol : MDT
# INFO:Details:Sleeping 1 sec
# 124/171 [====================>.........] - ETA: 0s - loss: 3.1854Epoch 1/10
# 171/171 [==============================] - 1s 5ms/step - loss: 3.1564
# 506/771 [==================>...........] - ETA: 1s - loss: 0.5059Epoch 3/10
# 610/771 [======================>.......] - ETA: 0s - loss: 0.5055.61
# INFO:Details:Sleeping 1 sec
# 171/171 [==============================] - 1s 5ms/step - loss: 2.5880
# 307/449 [===================>..........] - ETA: 0s - loss: 3.3753Epoch 4/10
# 771/771 [==============================] - 4s 5ms/step - loss: 0.5085
# 169/324 [==============>...............] - ETA: 0s - loss: 1596.2346Epoch 5/10
# 449/449 [==============================] - 2s 5ms/step - loss: 2.7452
#  24/723 [..............................] - ETA: 3s - loss: 831.5518Epoch 6/10
# 491/771 [==================>...........] - ETA: 1s - loss: 0.047857
# INFO:Details:Sleeping 1 sec
# 171/171 [==============================] - 1s 4ms/step - loss: 1.9928
# 514/771 [===================>..........] - ETA: 1s - loss: 0.051893Epoch 5/10
# 324/324 [==============================] - 3s 5ms/step - loss: 841.9395
#  68/171 [==========>...................] - ETA: 0s - loss: 1.8523Epoch 2/10
# 108/324 [=========>....................] - ETA: 0s - loss: 23.5160
# INFO:Details:Sleeping 1 sec
# 171/171 [==============================] - 1s 5ms/step - loss: 1.6680
# 205/449 [============>.................] - ETA: 1s - loss: 1.4140Epoch 6/10
# 771/771 [==============================] - 4s 5ms/step - loss: 0.0631
#  79/171 [============>.................] - ETA: 0s - loss: 1.46969Epoch 10/10
# 171/171 [==============================] - 1s 4ms/step - loss: 1.6488
#  96/771 [==>...........................] - ETA: 2s - loss: 0.0431Epoch 7/10
# 324/324 [==============================] - 1s 4ms/step - loss: 25.2851
# 130/771 [====>.........................] - ETA: 2s - loss: 0.0448Epoch 3/10
# 488/771 [=================>............] - ETA: 1s - loss: 0.55327
# INFO:Details:Sleeping 1 sec
# 449/449 [==============================] - 2s 5ms/step - loss: 4.7786
# Epoch 7/10
# 171/171 [==============================] - 1s 5ms/step - loss: 1.8720
# Epoch 8/10
# 697/771 [==========================>...] - ETA: 0s - loss: 0.5522
# INFO:Details:Sleeping 1 sec
# 723/723 [==============================] - 5s 5ms/step - loss: 156.5152
# 156/171 [==========================>...] - ETA: 0s - loss: 1.7590Epoch 2/10
# 171/171 [==============================] - 1s 4ms/step - loss: 1.7095
#  13/723 [..............................] - ETA: 3s - loss: 0.1273 Epoch 9/10
# 771/771 [==============================] - 4s 5ms/step - loss: 0.5639
# 312/324 [===========================>..] - ETA: 0s - loss: 25.2703Epoch 6/10
# 324/324 [==============================] - 2s 5ms/step - loss: 24.4992
# Epoch 4/10
# 126/723 [====>.........................] - ETA: 3s - loss: 0.1851
# INFO:Details:Sleeping 1 sec
# 171/171 [==============================] - 1s 6ms/step - loss: 1.5879
# 616/771 [======================>.......] - ETA: 0s - loss: 0.0799Epoch 10/10
# 449/449 [==============================] - 2s 5ms/step - loss: 2.1528
# 194/723 [=======>......................] - ETA: 3s - loss: 0.2110Epoch 8/10
# 771/771 [==============================] - 4s 5ms/step - loss: 0.0747
# INFO:Details:Sleeping 1 sec
# 324/324 [==============================] - 2s 5ms/step - loss: 25.7709
# 171/171 [==============================] - 1s 5ms/step - loss: 1.6941
# Epoch 5/10
# 1/1 [==============================] - 0s 268ms/step loss: 0.17
# 1/1 [==============================] - 0s 23ms/step- loss: 0.17
# 1/1 [==============================] - 0s 243ms/step loss: 0.172
# 1/1 [==============================] - 0s 19ms/step- loss: 2.41
# 1/1 [==============================] - 0s 32ms/step- loss: 0.16
# 1/1 [==============================] - 0s 25ms/step- loss: 2.42
# 1/1 [==============================] - 0s 31ms/step- loss: 0.16
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step- loss: 0.15
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step- loss: 2.217
# 1/1 [==============================] - 0s 24ms/step- loss: 0.15
# 1/1 [==============================] - 0s 30ms/step- loss: 2.17
# 525/723 [====================>.........] - ETA: 1s - loss: 0.1616
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 31ms/step- loss: 26.9347
# 1/1 [==============================] - 0s 22ms/step- loss: 26.12
# 1/1 [==============================] - 0s 20ms/step- loss: 0.15
# 1/1 [==============================] - 0s 22ms/step- loss: 25.57
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step- loss: 26.91
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step- loss: 0.15
# 1/1 [==============================] - 0s 28ms/step- loss: 0.59
# 1/1 [==============================] - 0s 27ms/step- loss: 25.01
# 1/1 [==============================] - 0s 24ms/step- loss: 2.09
# 449/449 [==============================] - 2s 5ms/step - loss: 2.1073
# Epoch 9/10
# 1/1 [==============================] - 0s 22ms/step- loss: 10.07
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step- loss: 2.440
# 1/1 [==============================] - 0s 26ms/step- loss: 24.62
# 1/1 [==============================] - 0s 22ms/step- loss: 23.96
# 324/324 [==============================] - 2s 5ms/step - loss: 24.3810
# 1/1 [==============================] - 0s 21ms/step
# Epoch 6/10
# 1/1 [==============================] - 0s 21ms/step- loss: 3.28
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step- loss: 3.90
# 723/723 [==============================] - 4s 5ms/step - loss: 0.1674
# 1/1 [==============================] - 0s 20ms/step
# Epoch 3/10
#   1/723 [..............................] - ETA: 16s - loss: 0.1618
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 23ms/step- loss: 4.68
# 1/1 [==============================] - 0s 21ms/step- loss: 0.063
# 1/1 [==============================] - 0s 22ms/step- loss: 0.07
# 1/1 [==============================] - 0s 24ms/step- loss: 0.57
# 1/1 [==============================] - 0s 20ms/step- loss: 0.15
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step- loss: 0.20
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step- loss: 0.21
# 1/1 [==============================] - 0s 19ms/step
# 771/771 [==============================] - 4s 5ms/step - loss: 0.5732
# 134/324 [===========>..................] - ETA: 0s - loss: 31.9772Epoch 7/10
# 1/1 [==============================] - 0s 21ms/step- loss: 30.07
# 1/1 [==============================] - 0s 23ms/step- loss: 0.21
# 1/1 [==============================] - 0s 26ms/step- loss: 1.04
# 1/1 [==============================] - 0s 19ms/step- loss: 0.77
# 1/1 [==============================] - 0s 22ms/step- loss: 0.62
# 1/1 [==============================] - 0s 37ms/step- loss: 0.20
# 1/1 [==============================] - 0s 22ms/step- loss: 0.67
# 1/1 [==============================] - 0s 23ms/step- loss: 0.62
# 1/1 [==============================] - 0s 21ms/step- loss: 24.01
# 1/1 [==============================] - 0s 29ms/step- loss: 26.67
# 1/1 [==============================] - 0s 19ms/step- loss: 26.14
# 111/771 [===>..........................] - ETA: 3s - loss: 0.6240
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 23ms/step- loss: 25.64
# 1/1 [==============================] - 0s 24ms/step- loss: 0.690
# 1/1 [==============================] - 0s 20ms/step- loss: 0.19
# 1/1 [==============================] - ETA: 0s: 0s - loss: 25.2782
# INFO:Details:Thread Spawn : 5 : Done
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step- loss: 0.18
# INFO:Details:Thread Spawn : 8 : Done
# 324/324 [==============================] - 1s 4ms/step - loss: 24.1495
# 315/449 [====================>.........] - ETA: 0s - loss: 5.2863Epoch 7/10
# 449/449 [==============================] - 2s 4ms/step - loss: 5.0204
# Epoch 10/10
# 477/771 [=================>............] - ETA: 0s - loss: 0.5435
# INFO:Details:Thread Join : 4
# INFO:Details:Thread Join : 5
# INFO:Details:Thread Join : 8
# 294/324 [==========================>...] - ETA: 0s - loss: 22.1529
# INFO:Details:t[modelNumber] = 11
# INFO:Details:Q : put11
# INFO:Details:Thread Spawn : 12 : Starting
# INFO:Details:Model number : 11 :: Ticker Symbol : V
# INFO:Details:t[modelNumber] = 12
# Model number :  11  :: Ticker Symbol :  V
# 178/449 [==========>...................] - ETA: 0s - loss: 3.9180
# INFO:Details:Q : put12
# INFO:Details:Thread Spawn : 13 : Starting
# Model number :  12  :: Ticker Symbol :  QRVO
# 493/771 [==================>...........] - ETA: 0s - loss: 0.5359
# INFO:Details:Model number : 12 :: Ticker Symbol : QRVO
# 307/324 [===========================>..] - ETA: 0s - loss: 21.4504
# INFO:Details:Sleeping 1 sec
# 324/324 [==============================] - 1s 3ms/step - loss: 21.6567
# 619/723 [========================>.....] - ETA: 0s - loss: 0.1658Epoch 8/10
# 627/723 [=========================>....] - ETA: 0s - loss: 0.1671Epoch 1/10
# Epoch 1/10
# 723/723 [==============================] - 3s 4ms/step - loss: 0.1587
# Epoch 4/10
# 677/771 [=========================>....] - ETA: 0s - loss: 0.5029
# INFO:Details:Sleeping 1 sec
# 449/449 [==============================] - 2s 4ms/step - loss: 4.3248
# 771/771 [==============================] - 3s 4ms/step - loss: 0.5108
# Epoch 8/10
# 1/1 [==============================] - 0s 317ms/step loss: 17.30
# 1/1 [==============================] - 0s 24ms/step- loss: 20.09
# 324/324 [==============================] - 2s 5ms/step - loss: 19.7732
#  74/771 [=>............................] - ETA: 2s - loss: 0.4434Epoch 9/10
# 1/1 [==============================] - 0s 25ms/step- loss: 3.87
# 1/1 [==============================] - 0s 25ms/step- loss: 0.466
#  11/213 [>.............................] - ETA: 1s - loss: 8570.7021
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 24ms/step- loss: 0.50
# 1/1 [==============================] - 0s 24ms/step- loss: 13.01
# 1/1 [==============================] - 0s 21ms/step- loss: 0.1691
# 1/1 [==============================] - 0s 26ms/step- loss: 0.525
# 114/114 [==============================] - 2s 5ms/step - loss: 5.8002
# 207/771 [=======>......................] - ETA: 2s - loss: 0.5276Epoch 2/10
# 1/1 [==============================] - 0s 19ms/step- loss: 0.1617
# 1/1 [==============================] - 0s 20ms/step- loss: 0.16
# 1/1 [==============================] - 0s 23ms/step- loss: 0.15.292
# 1/1 [==============================] - 0s 18ms/step- loss: 12.20
# 1/1 [==============================] - 0s 24ms/step- loss: 11.96
# 213/213 [==============================] - 3s 5ms/step - loss: 3439.9082
# Epoch 2/10
# 1/1 [==============================] - 0s 32ms/step- loss: 999.22
# INFO:Details:Sleeping 1 sec
# 114/114 [==============================] - 1s 5ms/step - loss: 5.0529
# 248/324 [=====================>........] - ETA: 0s - loss: 15.9844Epoch 3/10
# 1/1 [==============================] - 0s 46ms/step- loss: 1047.92
# 1/1 [==============================] - 0s 39ms/step- loss: 19.35
# 1/1 [==============================] - 0s 33ms/step- loss: 19.46
# 324/324 [==============================] - 2s 5ms/step - loss: 20.0026
#  92/213 [===========>..................] - ETA: 0s - loss: 831.6102Epoch 10/10
# 1/1 [==============================] - 0s 27ms/step- loss: 5.17
# 1/1 [==============================] - 0s 21ms/step- loss: 0.571
# 1/1 [==============================] - 0s 27ms/step- loss: 14.80
# 114/114 [==============================] - 1s 7ms/step - loss: 4.7728
# 624/723 [========================>.....] - ETA: 0s - loss: 0.1496Epoch 4/10
# 1/1 [==============================] - 0s 26ms/step- loss: 0.14
#  11/114 [=>............................] - ETA: 0s - loss: 3.1535
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 28ms/step- loss: 3.42
# 1/1 [==============================] - 0s 19ms/step- loss: 446.95
# 213/213 [==============================] - 1s 6ms/step - loss: 420.0587
# 1/1 [==============================] - ETA: 0sEpoch 3/10s: 0.5190
# 1/1 [==============================] - 0s 22ms/step- loss: 0.15
# 1/1 [==============================] - 0s 24ms/step- loss: 4.24
# 723/723 [==============================] - 4s 5ms/step - loss: 0.1557
# 104/114 [==========================>...] - ETA: 0s - loss: 4.7076Epoch 5/10
# 114/114 [==============================] - 1s 6ms/step - loss: 4.8911
# 1/1 [==============================] - 0s 24ms/step- loss: 14.85
# Epoch 5/10
# 1/1 [==============================] - 0s 24ms/step- loss: 14.10
# 1/1 [==============================] - 0s 46ms/step- loss: 0.11
#  51/114 [============>.................] - ETA: 0s - loss: 3.7374
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 66ms/step- loss: 0.51
# 1/1 [==============================] - 0s 28ms/step- loss: 0.15
# 254/324 [======================>.......] - ETA: 0s - loss: 15.0971
# INFO:Details:Thread Spawn : 7 : Done
# 114/114 [==============================] - 1s 6ms/step - loss: 4.3997
# Epoch 6/10
# 324/324 [==============================] - 2s 6ms/step - loss: 18.4376
# 213/213 [==============================] - 1s 6ms/step - loss: 1.2806
# Epoch 4/10
# 771/771 [==============================] - 4s 5ms/step - loss: 0.5678
# Epoch 9/10
# 114/114 [==============================] - 1s 4ms/step - loss: 4.2395
#  48/213 [=====>........................] - ETA: 0s - loss: 0.5713Epoch 7/10
# 1/1 [==============================] - 0s 263ms/step loss: 0.55
# 1/1 [==============================] - 0s 23ms/step- loss: 0.59
# INFO:Details:Thread Join : 8
# INFO:Details:Thread Join : 7
#  41/114 [=========>....................] - ETA: 0s - loss: 5.0095
# INFO:Details:t[modelNumber] = 13
# INFO:Details:Q : put13
# INFO:Details:Thread Spawn : 14 : Starting
# Model number :  13  :: Ticker Symbol :  A
# INFO:Details:Model number : 13 :: Ticker Symbol : A
#  54/771 [=>............................] - ETA: 3s - loss: 2.2774
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 30ms/step- loss: 4.74
# 1/1 [==============================] - 0s 35ms/step- loss: 4.281
#  99/771 [==>...........................] - ETA: 3s - loss: 1.3809Epoch 1/10
# 1/1 [==============================] - 0s 29ms/step- loss: 0.15
# 114/114 [==============================] - 1s 5ms/step - loss: 4.1734
# 168/213 [======================>.......] - ETA: 0s - loss: 0.6612Epoch 8/10
# 1/1 [==============================] - 0s 24ms/step- loss: 1.11
# 213/213 [==============================] - 1s 5ms/step - loss: 0.6842
# Epoch 5/10
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 41ms/step- loss: 0.96
#  49/213 [=====>........................] - ETA: 0s - loss: 0.6705
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 35ms/step
# 114/114 [==============================] - 1s 6ms/step - loss: 4.0866
# 247/771 [========>.....................] - ETA: 3s - loss: 0.8984Epoch 9/10
# 1/1 [==============================] - 0s 36ms/step- loss: 0.812
# 1/1 [==============================] - 0s 20ms/step- loss: 0.15
# 1/1 [==============================] - 0s 25ms/step- loss: 0.76
# 1/1 [==============================] - 0s 21ms/step- loss: 0.79
# 1/1 [==============================] - 0s 23ms/step- loss: 0.15
# 1/1 [==============================] - 0s 23ms/step- loss: 0.82
# 114/114 [==============================] - 1s 6ms/step - loss: 3.8322
# Epoch 10/10
# 1/1 [==============================] - 0s 28ms/step- loss: 0.786
# 209/213 [============================>.] - ETA: 0s - loss: 0.6890
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 25ms/step
# 213/213 [==============================] - 1s 6ms/step - loss: 0.6804
# 624/723 [========================>.....] - ETA: 0s - loss: 0.1553Epoch 6/10
# 1/1 [==============================] - 0s 21ms/step- loss: 0.96
# 1/1 [==============================] - 0s 31ms/step- loss: 0.15
# 1/1 [==============================] - 0s 48ms/step- loss: 0.7680.
# 114/114 [==============================] - 1s 6ms/step - loss: 4.0903
# 723/723 [==============================] - 4s 6ms/step - loss: 0.1580
# 1/1 [==============================] - 0s 34ms/step- loss: 0.74
# Epoch 6/10
# 1/1 [==============================] - 0s 278ms/step loss: 0.7149
# 1/1 [==============================] - 0s 17ms/step- loss: 0.73186
# 1/1 [==============================] - 0s 29ms/step- loss: 2121.14
#  62/723 [=>............................] - ETA: 4s - loss: 0.1065
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 32ms/step- loss: 0.726
# 1/1 [==============================] - 0s 43ms/step- loss: 0.6922
# 1/1 [==============================] - 0s 31ms/step- loss: 2120.57
# 1/1 [==============================] - 0s 40ms/step- loss: 2148.56
# 1/1 [==============================] - 0s 30ms/step- loss: 2191.27
# 1/1 [==============================] - 0s 26ms/step
# 213/213 [==============================] - 1s 7ms/step - loss: 0.6794
# 1/1 [==============================] - ETA: 0s: 0s - loss: 0.738561Epoch 7/10
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step- loss: 0.08
# 1/1 [==============================] - 0s 28ms/step- loss: 0.1542
# 1/1 [==============================] - 0s 33ms/step- loss: 0.745
# 1/1 [==============================] - 0s 29ms/step- loss: 0.72
# 1/1 [==============================] - 0s 24ms/step- loss: 0.721
# 1/1 [==============================] - 0s 20ms/step- loss: 0.1608
# 1/1 [==============================] - 0s 28ms/step- loss: 0.15.321
# 1/1 [==============================] - 0s 21ms/step- loss: 0.73
# 217/723 [========>.....................] - ETA: 3s - loss: 0.153782
# INFO:Details:Thread Spawn : 9 : Done
# 230/723 [========>.....................] - ETA: 2s - loss: 0.148487
# INFO:Details:Thread Join : 7
# INFO:Details:Thread Join : 9
# INFO:Details:t[modelNumber] = 14
# INFO:Details:Q : put14
# 1/1 [==============================] - 0s 22ms/step
# INFO:Details:Thread Spawn : 15 : Starting
# Model number :  14  :: Ticker Symbol :  FLT
#  97/213 [============>.................] - ETA: 0s - loss: 0.7101
# INFO:Details:Model number : 14 :: Ticker Symbol : FLT
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 21ms/step- loss: 0.719
# 771/771 [==============================] - 5s 6ms/step - loss: 0.6889
# 269/335 [=======================>......] - ETA: 0s - loss: 1772.3521Epoch 10/10
# 137/213 [==================>...........] - ETA: 0s - loss: 0.73091e-0Epoch 1/10
# 1/1 [==============================] - 0s 41ms/step- loss: 0.702
# 1/1 [==============================] - 0s 35ms/step- loss: 0.5301
# 335/335 [==============================] - 4s 7ms/step - loss: 1587.4144
# Epoch 2/10
# 1/1 [==============================] - 0s 28ms/step- loss: 243.34
# 213/213 [==============================] - 1s 6ms/step - loss: 0.6734
# 1/1 [==============================] - 0s 25ms/step
# Epoch 8/10
# 1/1 [==============================] - 0s 21ms/step- loss: 0.16
# 101/771 [==>...........................] - ETA: 4s - loss: 0.57655
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 25ms/step- loss: 0.59
# 1/1 [==============================] - 0s 43ms/step- loss: 0.53
# 1/1 [==============================] - 0s 22ms/step- loss: 0.666
# 1/1 [==============================] - 0s 26ms/step- loss: 205.15
# 1/1 [==============================] - 0s 30ms/step- loss: 0.664
# 1/1 [==============================] - 0s 27ms/step- loss: 159.55
# 1/1 [==============================] - 0s 22ms/step- loss: 140.80
# 1/1 [==============================] - 0s 23ms/step- loss: 128.37
# 576/723 [======================>.......] - ETA: 0s - loss: 0.16519
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 23ms/step- loss: 117.86
# 213/213 [==============================] - 1s 6ms/step - loss: 0.6681
# 240/335 [====================>.........] - ETA: 0s - loss: 113.5439Epoch 9/10
# 1/1 [==============================] - 0s 21ms/step- loss: 0.63
# 1/1 [==============================] - 0s 26ms/step- loss: 0.54
# 1/1 [==============================] - 0s 27ms/step- loss: 0.55
# 1/1 [==============================] - 0s 29ms/step- loss: 0.16
# 1/1 [==============================] - 0s 31ms/step- loss: 84.78
# INFO:Details:Thread Spawn : 12 : Done
# 335/335 [==============================] - 2s 6ms/step - loss: 83.7885
# 380/771 [=============>................] - ETA: 2s - loss: 0.5189Epoch 3/10
#  56/335 [====>.........................] - ETA: 1s - loss: 1.4307
# INFO:Details:Thread Join : 9
# INFO:Details:Thread Join : 12
# INFO:Details:t[modelNumber] = 15
# INFO:Details:Q : put15
# INFO:Details:Thread Spawn : 16 : Starting
# 148/213 [===================>..........] - ETA: 0s - loss: 0.5824
# INFO:Details:Sleeping 1 sec
# 707/723 [============================>.] - ETA: 0s - loss: 0.1680 MO
# INFO:Details:Model number : 15 :: Ticker Symbol : MO
# 723/723 [==============================] - 5s 6ms/step - loss: 0.1692
#  74/335 [=====>........................] - ETA: 1s - loss: 1.3350Epoch 7/10
# 105/335 [========>.....................] - ETA: 1s - loss: 1.7290Epoch 1/10
# 213/213 [==============================] - 1s 7ms/step - loss: 0.6665
# 499/771 [==================>...........] - ETA: 1s - loss: 0.5510Epoch 10/10
# 567/771 [=====================>........] - ETA: 1s - loss: 0.5483
# INFO:Details:Sleeping 1 sec
# 213/213 [==============================] - 1s 6ms/step - loss: 0.6601
# 335/335 [==============================] - 2s 6ms/step - loss: 3.7046
# Epoch 4/10
#  17/335 [>.............................] - ETA: 2s - loss: 1.38714
# INFO:Details:Sleeping 1 sec
# 771/771 [==============================] - 5s 7ms/step - loss: 0.5436
# 1/1 [==============================] - 0s 331ms/step loss: 1.33
# 173/173 [==============================] - 5s 6ms/step - loss: 6237.4829
# Epoch 2/10
# 1/1 [==============================] - 0s 20ms/step- loss: 2.96
# 1/1 [==============================] - 0s 21ms/step- loss: 0.18
# 1/1 [==============================] - 0s 26ms/step- loss: 0.183
# 1/1 [==============================] - 0s 238ms/step loss: 12.84
# 1/1 [==============================] - 0s 22ms/step- loss: 4.4138
# 1/1 [==============================] - 0s 27ms/step- loss: 3.98670
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step- loss: 8.835
# 1/1 [==============================] - 0s 20ms/step- loss: 923.40
# 1/1 [==============================] - 0s 22ms/step- loss: 3.759
# 1/1 [==============================] - 0s 23ms/step- loss: 0.18
# 1/1 [==============================] - 0s 21ms/step- loss: 7.740
# 1/1 [==============================] - 0s 17ms/step
# ...
# 1/1 [==============================] - 0s 24ms/step- loss: 3.692
# 121/267 [============>.................] - ETA: 0s - loss: 3.60121
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 25ms/step- loss: 3.433
# 1/1 [==============================] - 0s 28ms/step- loss: 1.29
# 1/1 [==============================] - 0s 25ms/step- loss: 1.260
# 1/1 [==============================] - 0s 28ms/step- loss: 265.48
# 1/1 [==============================] - 0s 32ms/step- loss: 2.951
# 1/1 [==============================] - 0s 34ms/step- loss: 0.94
# 1/1 [==============================] - 0s 28ms/step- loss: 1.22
# 1/1 [==============================] - 0s 28ms/step- loss: 3.09
# 1/1 [==============================] - 0s 25ms/step- loss: 2.96
# 1/1 [==============================] - 0s 33ms/step- loss: 0.96
# 424/424 [==============================] - 5s 7ms/step - loss: 220.4651
# 221/267 [=======================>......] - ETA: 0s - loss: 2.9895Epoch 2/10
# 1/1 [==============================] - 0s 39ms/step- loss: 2.95
# 1/1 [==============================] - 0s 36ms/step- loss: 2.96
# 1/1 [==============================] - 0s 24ms/step- loss: 2.94
# 1/1 [==============================] - 0s 37ms/step- loss: 1.109
# 267/267 [==============================] - 2s 7ms/step - loss: 3.1204
# 1/1 [==============================] - ETA: 0s: 2s - loss: 1.0830Epoch 6/10
# 1/1 [==============================] - 0s 25ms/step
# 394/725 [===============>..............] - ETA: 2s - loss: 1.0789
# INFO:Details:Sleeping 1 sec
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step- loss: 1.06
#  18/267 [=>............................] - ETA: 1s - loss: 4.1963
# INFO:Details:Thread Spawn : 93 : Done
# 1/1 [==============================] - 0s 25ms/step- loss: 1.05
# 1/1 [==============================] - 0s 23ms/step- loss: 0.336
# 1/1 [==============================] - 0s 22ms/step- loss: 0.840
# 1/1 [==============================] - 0s 33ms/step- loss: 0.31
# INFO:Details:Thread Spawn : 95 : Done
# 432/432 [==============================] - 6s 13ms/step - loss: 0.7852
# 138/267 [==============>...............] - ETA: 0s - loss: 3.2316Epoch 6/10
# 261/424 [=================>............] - ETA: 0s - loss: 0.2925
# INFO:Details:Thread Join : 92
# INFO:Details:Thread Join : 93
# INFO:Details:Thread Join : 95
# 616/725 [========================>.....] - ETA: 0s - loss: 1.0439
# INFO:Details:t[modelNumber] = 99
# INFO:Details:Q : put99
#  99/432 [=====>........................] - ETA: 1s - loss: 0.7472Model number :  99
# INFO:Details:Model number : 99 :: Ticker Symbol : IPGP
#  :: Ticker Symbol :  IPGP
# 267/267 [==============================] - 1s 5ms/step - loss: 3.0890
# 301/424 [====================>.........] - ETA: 0s - loss: 0.2946Epoch 7/10
# 319/424 [=====================>........] - ETA: 0s - loss: 0.2918Epoch 1/10
# 725/725 [==============================] - 5s 6ms/step - loss: 0.9605
# 402/424 [===========================>..] - ETA: 0s - loss: 0.3110Epoch 10/10
# 424/424 [==============================] - 2s 5ms/step - loss: 0.3039
#  20/725 [..............................] - ETA: 3s - loss: 0.6992Epoch 3/10
# 267/267 [==============================] - 2s 6ms/step - loss: 3.0197
# Epoch 8/10
# 432/432 [==============================] - 2s 5ms/step - loss: 0.9195
# 195/424 [============>.................] - ETA: 1s - loss: 0.2739Epoch 7/10
# 267/267 [==============================] - 1s 5ms/step - loss: 3.0577
# Epoch 9/10
# 424/424 [==============================] - 2s 5ms/step - loss: 0.2864
# 183/232 [======================>.......] - ETA: 0s - loss: 3705.9248Epoch 4/10
# 232/232 [==============================] - 3s 5ms/step - loss: 2923.0476
# 510/725 [====================>.........] - ETA: 1s - loss: 0.8242Epoch 2/10
# 432/432 [==============================] - 2s 5ms/step - loss: 1.4154
# 173/424 [===========>..................] - ETA: 1s - loss: 0.2751Epoch 8/10
# 267/267 [==============================] - 1s 5ms/step - loss: 3.1081
# 725/725 [==============================] - 4s 5ms/step - loss: 0.8750
# Epoch 10/10
# 232/232 [==============================] - 1s 5ms/step - loss: 14.2545
# 277/424 [==================>...........] - ETA: 0s - loss: 0.2741Epoch 3/10
# 1/1 [==============================] - 0s 369ms/step loss: 8.528
# 1/1 [==============================] - 0s 25ms/step- loss: 19.93
# 1/1 [==============================] - 0s 32ms/step- loss: 0.27
# 1/1 [==============================] - 0s 24ms/step- loss: 0.57
# 1/1 [==============================] - 0s 31ms/step- loss: 17.05
# 424/424 [==============================] - 2s 5ms/step - loss: 0.2957
# 252/432 [================>.............] - ETA: 0s - loss: 0.5438Epoch 5/10
# 1/1 [==============================] - 0s 33ms/step- loss: 0.51
# 1/1 [==============================] - 0s 28ms/step- loss: 2.76
# 1/1 [==============================] - 0s 31ms/step- loss: 0.543
# 267/267 [==============================] - 1s 5ms/step - loss: 2.9919
# 232/232 [==============================] - 1s 5ms/step - loss: 14.7246
# 1/1 [==============================] - ETA: 0s: 0s - loss: 0.5611Epoch 4/10
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step- loss: 6.01
# 1/1 [==============================] - 0s 27ms/step- loss: 0.64
# 1/1 [==============================] - 0s 282ms/step loss: 0.63
# 1/1 [==============================] - 0s 32ms/step- loss: 0.64
# 1/1 [==============================] - 0s 31ms/step- loss: 0.31
# 1/1 [==============================] - 0s 21ms/step- loss: 0.61
# 432/432 [==============================] - 2s 6ms/step - loss: 0.6251
# 1/1 [==============================] - 0s 139ms/step
# Epoch 9/10
# 1/1 [==============================] - 0s 28ms/step- loss: 9.699
# 1/1 [==============================] - 0s 32ms/step- loss: 0.28
# 1/1 [==============================] - 0s 34ms/step- loss: 0.22
# 1/1 [==============================] - 0s 29ms/step- loss: 10.72
# 1/1 [==============================] - 0s 28ms/step- loss: 10.73
# 1/1 [==============================] - 0s 27ms/step- loss: 0.425
# 1/1 [==============================] - 0s 25ms/step- loss: 0.26
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step- loss: 0.25
# 1/1 [==============================] - 0s 24ms/step- loss: 0.25
# 1/1 [==============================] - 0s 35ms/step- loss: 11.61
# 232/232 [==============================] - 1s 6ms/step - loss: 14.0151
# Epoch 5/10
# 1/1 [==============================] - 0s 28ms/step- loss: 0.24
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step- loss: 0.24
# 1/1 [==============================] - 0s 37ms/step- loss: 0.24
# 1/1 [==============================] - 0s 24ms/step- loss: 0.24
# 1/1 [==============================] - 0s 18ms/step- loss: 0.79
# 1/1 [==============================] - 0s 23ms/step- loss: 0.24
# 1/1 [==============================] - 0s 21ms/step- loss: 0.24
# 1/1 [==============================] - 0s 22ms/step- loss: 0.24
# 1/1 [==============================] - 0s 31ms/step- loss: 0.24
# 1/1 [==============================] - 0s 24ms/step- loss: 0.25
# 424/424 [==============================] - 2s 6ms/step - loss: 0.2520
# 227/432 [==============>...............] - ETA: 1s - loss: 0.8410Epoch 6/10
# 1/1 [==============================] - 0s 27ms/step- loss: 0.87
# 1/1 [==============================] - 0s 25ms/step- loss: 14.34
# 1/1 [==============================] - 0s 30ms/step- loss: 0.92
# 1/1 [==============================] - 0s 26ms/step- loss: 0.91
# 1/1 [==============================] - 0s 23ms/step- loss: 0.14
# 1/1 [==============================] - 0s 29ms/step- loss: 0.16
# 1/1 [==============================] - 0s 20ms/step- loss: 0.85
# 1/1 [==============================] - 0s 25ms/step
# 232/232 [==============================] - 1s 5ms/step - loss: 16.2881
# 106/424 [======>.......................] - ETA: 1s - loss: 0.2103Epoch 6/10
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step- loss: 16.81
# 1/1 [==============================] - 0s 28ms/step- loss: 0.24
# 1/1 [==============================] - 0s 28ms/step- loss: 0.87
# 133/424 [========>.....................] - ETA: 1s - loss: 0.2498
# INFO:Details:Thread Spawn : 91 : Done
# 1/1 [==============================] - 0s 22ms/step- loss: 0.252
# 1/1 [==============================] - 0s 21ms/step- loss: 0.86
# 1/1 [==============================] - 0s 25ms/step- loss: 0.25
# 432/432 [==============================] - 2s 6ms/step - loss: 0.8184
# Epoch 10/10
# 1/1 [==============================] - 0s 24ms/step- loss: 0.35
# 1/1 [==============================] - 0s 22ms/step- loss: 12.02
# INFO:Details:Thread Join : 95
# INFO:Details:Thread Join : 91
# 1/1 [==============================] - 0s 24ms/step- loss: 0.40
# 1/1 [==============================] - 0s 20ms/step- loss: 12.43
# 1/1 [==============================] - 0s 24ms/step- loss: 14.53
# 1/1 [==============================] - 0s 17ms/step- loss: 14.03
# 232/232 [==============================] - 1s 4ms/step - loss: 13.7076
# Epoch 7/10
# 1/1 [==============================] - 0s 26ms/step- loss: 0.23
# INFO:Details:Thread Spawn : 97 : Done
# 424/424 [==============================] - 2s 4ms/step - loss: 0.2412
# 201/432 [============>.................] - ETA: 0s - loss: 0.5569Epoch 7/10
# 232/232 [==============================] - 1s 3ms/step - loss: 13.9554
# Epoch 8/10
# 144/424 [=========>....................] - ETA: 0s - loss: 0.2117
# INFO:Details:Thread Join : 91
# INFO:Details:Thread Join : 97
# 432/432 [==============================] - 1s 3ms/step - loss: 0.6008
# 1/1 [==============================] - 0s 155ms/step loss: 0.23
# 1/1 [==============================] - 0s 17ms/step- loss: 21.04
# 1/1 [==============================] - 0s 15ms/step- loss: 20.77
# 1/1 [==============================] - 0s 19ms/step- loss: 0.22
# 232/232 [==============================] - 1s 3ms/step - loss: 20.0474
# 368/424 [=========================>....] - ETA: 0s - loss: 0.2172Epoch 9/10
# 1/1 [==============================] - 0s 17ms/step- loss: 19.12
# 1/1 [==============================] - 0s 18ms/step- loss: 39.93
# 1/1 [==============================] - 0s 17ms/step- loss: 29.39
# 424/424 [==============================] - 1s 3ms/step - loss: 0.2093
#  53/232 [=====>........................] - ETA: 0s - loss: 21.7435Epoch 8/10
# 1/1 [==============================] - 0s 19ms/step- loss: 19.40
# 1/1 [==============================] - 0s 16ms/step- loss: 16.69
# 1/1 [==============================] - 0s 15ms/step- loss: 15.35
# 1/1 [==============================] - 0s 20ms/step- loss: 13.38
# 1/1 [==============================] - 0s 18ms/step- loss: 12.96
# 1/1 [==============================] - 0s 20ms/step- loss: 12.67
# 1/1 [==============================] - 0s 17ms/step- loss: 0.18
# 1/1 [==============================] - 0s 17ms/step- loss: 14.35
# 232/232 [==============================] - 1s 3ms/step - loss: 13.8349
# 1/1 [==============================] - 0s 16ms/step
# Epoch 10/10
# 1/1 [==============================] - 0s 20ms/step- loss: 0.22
# 1/1 [==============================] - 0s 17ms/step- loss: 0.21
# 1/1 [==============================] - 0s 18ms/step- loss: 0.21
# 1/1 [==============================] - 0s 17ms/step- loss: 0.22
# 1/1 [==============================] - 0s 15ms/step- loss: 0.21
# 1/1 [==============================] - 0s 17ms/step- loss: 0.21
# 1/1 [==============================] - 0s 19ms/step- loss: 9.40
# 1/1 [==============================] - 0s 20ms/step- loss: 9.97
# 1/1 [==============================] - 0s 19ms/step- loss: 12.68
# 1/1 [==============================] - 0s 17ms/step- loss: 0.20
# 1/1 [==============================] - 0s 20ms/step- loss: 0.19
# 1/1 [==============================] - 0s 21ms/step- loss: 11.80
# 232/232 [==============================] - 1s 3ms/step - loss: 11.6952
# 1/1 [==============================] - 0s 22ms/step- loss: 0.19
# 424/424 [==============================] - 1s 3ms/step - loss: 0.1913
# Epoch 9/10
# 1/1 [==============================] - 0s 20ms/step- loss: 0.02
# INFO:Details:Thread Spawn : 96 : Done
# 1/1 [==============================] - 0s 145ms/step loss: 0.12
# 1/1 [==============================] - 0s 15ms/step- loss: 0.11
# 1/1 [==============================] - 0s 19ms/step- loss: 0.15
# 1/1 [==============================] - 0s 18ms/step- loss: 0.15
# 1/1 [==============================] - 0s 19ms/step- loss: 0.14
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step- loss: 0.15
# 1/1 [==============================] - 0s 16ms/step- loss: 0.14
# 1/1 [==============================] - 0s 17ms/step- loss: 0.15
# 1/1 [==============================] - 0s 15ms/step- loss: 0.16
# 1/1 [==============================] - 0s 15ms/step- loss: 0.16
# 1/1 [==============================] - 0s 17ms/step- loss: 0.15
# 1/1 [==============================] - 0s 15ms/step- loss: 0.15
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step- loss: 0.15
# 1/1 [==============================] - 0s 16ms/step- loss: 0.17
# INFO:Details:Thread Join : 97
# INFO:Details:Thread Join : 96
# 1/1 [==============================] - 0s 16ms/step- loss: 0.18
# 1/1 [==============================] - 0s 15ms/step- loss: 0.18
# 1/1 [==============================] - 0s 14ms/step- loss: 0.17
# 1/1 [==============================] - 0s 13ms/step- loss: 0.18
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step- loss: 0.17
# 1/1 [==============================] - 0s 13ms/step- loss: 0.17
# 1/1 [==============================] - 0s 14ms/step- loss: 0.17
# 424/424 [==============================] - 1s 3ms/step - loss: 0.1747
# Epoch 10/10
# 1/1 [==============================] - 0s 14ms/step- loss: 0.02
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step- loss: 0.16
# 1/1 [==============================] - 0s 12ms/step- loss: 0.16
# 1/1 [==============================] - 0s 15ms/step- loss: 0.14
# 1/1 [==============================] - 0s 13ms/step- loss: 0.19
# INFO:Details:Thread Spawn : 99 : Done
# 334/424 [======================>.......] - ETA: 0s - loss: 0.1619
# INFO:Details:Thread Join : 96
# INFO:Details:Thread Join : 99
# 424/424 [==============================] - 1s 2ms/step - loss: 0.1740
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# INFO:Details:Thread Spawn : 98 : Done
# INFO:Details:Running Threads : File : Close : End
# INFO:Phases:Making Models in Threads : End

# %%
print(RNN_forecast_dict.keys())

# %%
#RNN_forecast_df = pd.DataFrame.from_dict(RNN_forecast_dict, orient='index')

# %%
#RNN_forecast_dict['CSCO'].to_numpy()

# %%
##RNN_forecast_dict
